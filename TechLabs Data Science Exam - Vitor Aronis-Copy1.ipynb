# %% [markdown]
# <img src="TechLabs.png">

# %% [markdown]
# <h2>Please enter your full name here:</h2>

# %% [markdown]
# <p> This exam will test your knowledge in Data Science. </p>
# <p> We will test the following: </p>
#
# - Basic knowledge in Data Science
# - How to manipulate data
# - How to clean data
# - Further data analysis

# %% [markdown]
# <h2>1. Basic Knowledge Test</h2>

# %% [markdown]
# A) Create a dictionary and a list.

# %%
d = {1:"Brazil", 2:"Spain", 3:"France"}
print(d)
l = [34,67,98,24,65]
print(l)
# Out:
# {1: 'Brazil', 2: 'Spain', 3: 'France'}
# [34, 67, 98, 24, 65]

# %% [markdown]
# B) Create your own array containing multiple lists (at least 5 rows and 4 columns).

# %%
import numpy as np
a = np.random.randint(5, size=(5,4))
a
# Out:
# array([[2, 4, 3, 4],
#        [0, 3, 1, 4],
#        [3, 4, 3, 0],
#        [1, 2, 4, 3],
#        [1, 1, 2, 0]])

# %% [markdown]
# C) Convert your previous array into a pandas dataframe.

# %%
import pandas as pd
df = pd.DataFrame(a)
df
# Out:
#    0  1  2  3
# 0  2  4  3  4
# 1  0  3  1  4
# 2  3  4  3  0
# 3  1  2  4  3
# 4  1  1  2  0

# %% [markdown]
#  D) Please write a function that will start with the number 2 and will add 3 as long as the number is under 25.

# %%
b = 2
while b < 25:
    print(b)
    b = b + 3
else:
    print("Limit")
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# Limit

# %% [markdown]
# E) Briefly explain what a lambda function is and its benefits over using regular functions.

# %%
# A lambda function is a simplified function that can be created with no name but only with one expression

# %% [markdown]
# F) What is the difference between relational and non-relational databases?

# %%
# Relational Database store data in tables and roles. This allows to link information with keys. 
# While Non-relational Database use a storage model specific for each type of data being stored. 
# There are four main categories of non-relational databases:Key-value stores, Graph stores, Column stores, and Document stores.

# %% [markdown]
# <h2>2. Manipulating Data </h2>
#
# Dataset used: "AB_NYC_2019.csv" </p>
# In this part of the exam you will have to play around with a dataset and display subsets of the data.

# %%
# Place all packages you need here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# A) Load "AB_NYC_2019.csv",  drop all null values, and name it "df".

# %%
df = pd.read_csv("/Users/vitoraronis/Documents/TechLabs/AB_NYC_2019.csv")
df.dropna()
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
#          host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0             John            Brooklyn       Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan          Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan      East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan      Murray Hill  40.74767  -73.97500
# ...            ...                 ...              ...       ...        ...
# 48782        Rusaa           Manhattan  Upper East Side  40.78099  -73.95366
# 48790         H Ai              Queens         Flushing  40.75104  -73.81459
# 48799          Ben       Staten Island      Great Kills  40.54179  -74.14275
# 48805       Blaine               Bronx       Mott Haven  40.80787  -73.92400
# 48852    Christine            Brooklyn         Bushwick  40.69805  -73.92801
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room    149               1                  9  2018-10-19
# 1      Entire home/apt    225               1                 45  2019-05-21
# 3      Entire home/apt     89               1                270  2019-07-05
# 4      Entire home/apt     80              10                  9  2018-11-19
# 5      Entire home/apt    200               3                 74  2019-06-22
# ...                ...    ...             ...                ...         ...
# 48782     Private room    129               1                  1  2019-07-07
# 48790     Private room     45               1                  1  2019-07-07
# 48799     Private room    235               1                  1  2019-07-07
# 48805  Entire home/apt    100               1                  2  2019-07-07
# 48852     Private room     30               1                  1  2019-07-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# 5                   0.59                               1               129
# ...                  ...                             ...               ...
# 48782               1.00                               1               147
# 48790               1.00                               6               339
# 48799               1.00                               1                87
# 48805               2.00                               1                40
# 48852               1.00                               1                 1
#
# [38821 rows x 16 columns]

# %% [markdown]
# B) Within the dataframe "df", permanently rename the column "name" to "listing_name".

# %%
df = df.rename(columns={"name":"listing_name"})
df.head()
# Out:
#      id                                      listing_name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# C) Drop the column host_id. Save the new dataframe again under the name "df".

# %%
df.drop(["host_id"], axis="columns", inplace=True)
# Out:
#      id                                      listing_name    host_name  \
# 0  2539                Clean & quiet apt home by the park         John
# 1  2595                             Skylit Midtown Castle     Jennifer
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth
# 3  3831                   Cozy Entire Floor of Brownstone  LisaRoxanne
# 4  5022  Entire Apt: Spacious Studio/Loft by central park        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
# 3     89               1                270  2019-07-05               4.64
# 4     80              10                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %% [markdown]
# D) Only show listings with a price higher than the average price. Sort the dataframe by price in an ascending order.

# %%
print(df["price"].mean())
df[df["price"]>df["price"].mean()]
# Out:
# 152.7206871868289
#              id                                     listing_name  \
# 1          2595                            Skylit Midtown Castle
# 5          5099        Large Cozy 1 BR Apartment In Midtown East
# 16         7097                Perfect for Your Parents + Garden
# 19         7750                Huge 2 BR Upper East  Cental Park
# 20         7801                 Sweet and Spacious Brooklyn Loft
# ...         ...                                              ...
# 48872  36476675                                    Nycity-MyHome
# 48873  36477307                                Brooklyn paradise
# 48884  36482783      Brooklyn Oasis in the heart of Williamsburg
# 48886  36483010                  Comfy 1 Bedroom in Midtown East
# 48887  36483152  Garden Jewel Apartment in Williamsburg New York
#
#             host_name neighbourhood_group   neighbourhood  latitude  \
# 1            Jennifer           Manhattan         Midtown  40.75362
# 5               Chris           Manhattan     Murray Hill  40.74767
# 16               Jane            Brooklyn     Fort Greene  40.69169
# 19               Sing           Manhattan     East Harlem  40.79685
# 20              Chaya            Brooklyn    Williamsburg  40.71842
# ...               ...                 ...             ...       ...
# 48872             Ben           Manhattan  Hell's Kitchen  40.76236
# 48873  Clement & Rose            Brooklyn       Flatlands  40.63116
# 48884        Jonathan            Brooklyn    Williamsburg  40.71790
# 48886           Scott           Manhattan         Midtown  40.75561
# 48887           Melki            Brooklyn    Williamsburg  40.71232
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 1      -73.98377  Entire home/apt    225               1                 45
# 5      -73.97500  Entire home/apt    200               3                 74
# 16     -73.97185  Entire home/apt    215               2                198
# 19     -73.94872  Entire home/apt    190               7                  0
# 20     -73.95718  Entire home/apt    299               3                  9
# ...          ...              ...    ...             ...                ...
# 48872  -73.99255  Entire home/apt    260               3                  0
# 48873  -73.92616  Entire home/apt    170               1                  0
# 48884  -73.96238     Private room    190               7                  0
# 48886  -73.96723  Entire home/apt    200               6                  0
# 48887  -73.94220  Entire home/apt    170               1                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 1      2019-05-21               0.38                               2
# 5      2019-06-22               0.59                               1
# 16     2019-06-28               1.72                               1
# 19            NaN                NaN                               2
# 20     2011-12-28               0.07                               1
# ...           ...                ...                             ...
# 48872         NaN                NaN                               1
# 48873         NaN                NaN                               2
# 48884         NaN                NaN                               1
# 48886         NaN                NaN                               1
# 48887         NaN                NaN                               3
#
#        availability_365
# 1                   355
# 5                   129
# 16                  321
# 19                  249
# 20                    0
# ...                 ...
# 48872                 9
# 48873               363
# 48884               341
# 48886               176
# 48887               365
#
# [14879 rows x 15 columns]

# %% [markdown]
# E) Only show listings that have more than the average reviews and that are available for more than 10 nights (column "minimum_nights"). Sort the dataframe by reviews in a descending order.

# %%
print(df["number_of_reviews"].mean())
df[(df["number_of_reviews"]>df["number_of_reviews"].mean())&(df["minimum_nights"]>10)]
# Out:
# 23.274465691788528
#              id                                    listing_name  \
# 6          5121                                 BlissArtsSpace!
# 14         6090                   West Village Nest - Superhost
# 29         9657                Modern 1 BR / NYC / EAST VILLAGE
# 55        14377                Williamsburg 1 bedroom Apartment
# 63        16326      Comfortable 4-bedroom apt in family house.
# ...         ...                                             ...
# 37630  29838125         Beautiful Private Room 20 min to city X
# 37738  29903897  Spacious room with a double bed in heart of BK
# 37739  29904305   Comfy room with a sunroof in the heart of BK!
# 37740  29904478              Cozy room in the heart of Bushwick
# 38927  30441504          Large, Comfortable 2 Bedroom Apartment
#
#                  host_name neighbourhood_group       neighbourhood  latitude  \
# 6                    Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 14                   Alina           Manhattan        West Village  40.73530
# 29                    Dana           Manhattan        East Village  40.72920
# 55                  Joanna            Brooklyn        Williamsburg  40.70881
# 63                 Dimitri            Brooklyn    Prospect Heights  40.67811
# ...                    ...                 ...                 ...       ...
# 37630  Dee Daisy And Peter            Brooklyn  Bedford-Stuyvesant  40.68921
# 37738               Stella            Brooklyn            Bushwick  40.69243
# 37739               Stella            Brooklyn            Bushwick  40.69202
# 37740               Stella            Brooklyn            Bushwick  40.69276
# 38927                Susan           Manhattan            Kips Bay  40.74130
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 6      -73.95596     Private room     60              45                 49
# 14     -74.00525  Entire home/apt    120              90                 27
# 29     -73.98542  Entire home/apt    180              14                 29
# 55     -73.95930  Entire home/apt    150              30                105
# 63     -73.96428  Entire home/apt    200              30                143
# ...          ...              ...    ...             ...                ...
# 37630  -73.95035     Private room     65              30                 26
# 37738  -73.91528     Private room     50              30                 51
# 37739  -73.91487     Private room     46              30                 29
# 37740  -73.91465     Private room     35              30                 31
# 38927  -73.98145  Entire home/apt    275              30                 35
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 6      2017-10-05               0.40                               1
# 14     2018-10-31               0.22                               1
# 29     2019-04-19               0.24                               1
# 55     2019-06-22               0.90                               1
# 63     2019-01-26               1.33                               2
# ...           ...                ...                             ...
# 37630  2019-06-24               3.25                               4
# 37738  2019-06-10               6.32                               3
# 37739  2019-07-03               3.60                               3
# 37740  2019-07-07               3.94                               3
# 38927  2019-06-24               5.00                               1
#
#        availability_365
# 6                     0
# 14                    0
# 29                   67
# 55                   30
# 63                  297
# ...                 ...
# 37630               361
# 37738               227
# 37739               246
# 37740               316
# 38927               253
#
# [591 rows x 15 columns]

# %% [markdown]
# F) Display the number of listings per neighbourhood and only display those neighbourhoods with more than 1000 listings.

# %%
df_copy = df.groupby("neighbourhood")[["neighbourhood"]].count()
df_copy = df_copy.rename(columns={"neighbourhood":"n_listings"})
df_copy[df_copy["n_listings"]>1000]
# Out:
#                     n_listings
# neighbourhood
# Bedford-Stuyvesant        3714
# Bushwick                  2465
# Chelsea                   1113
# Crown Heights             1564
# East Harlem               1117
# East Village              1853
# Greenpoint                1115
# Harlem                    2658
# Hell's Kitchen            1958
# Midtown                   1545
# Upper East Side           1798
# Upper West Side           1971
# Williamsburg              3920

# %%
# %%capture
! pip install seaborn

# %% [markdown]
# G) Display the number of the different types of rooms (column "room_type") per neighbourhood.

# %%
df.groupby(["neighbourhood","room_type"]).first()
# Out:
#                                      id  \
# neighbourhood room_type
# Allerton      Entire home/apt    182177
#               Private room       498120
# Arden Heights Entire home/apt  22730139
#               Private room     28431734
# Arrochar      Entire home/apt    258838
# ...                                 ...
# Woodlawn      Shared room      19682018
# Woodrow       Entire home/apt   1798271
# Woodside      Entire home/apt    704838
#               Private room        18198
#               Shared room      33906887
#
#                                                                     listing_name  \
# neighbourhood room_type
# Allerton      Entire home/apt              A PRIVATE FLAT / APARTMENT- $SPECIAL$
#               Private room                                 Hi Traveler.. welcome
# Arden Heights Entire home/apt   Staten Island full size living space-lower level
#               Private room     Bright 2- Room apartment in a house next to tr...
# Arrochar      Entire home/apt                       Oceanview,close to Manhattan
# ...                                                                          ...
# Woodlawn      Shared room                 Room in basement apartment in Woodlawn
# Woodrow       Entire home/apt                      Spacious center hall colonial
# Woodside      Entire home/apt                       An Oasis in  the Big Apple 1
#               Private room                                 Little King of Queens
#               Shared room      New renovation cozy home 12 min train to Manha...
#
#                                        host_name neighbourhood_group  \
# neighbourhood room_type
# Allerton      Entire home/apt  Christian & Carla               Bronx
#               Private room                 Ellen               Bronx
# Arden Heights Entire home/apt              Nabil       Staten Island
#               Private room                  Olga       Staten Island
# Arrochar      Entire home/apt             Marina       Staten Island
# ...                                          ...                 ...
# Woodlawn      Shared room                Yesenia               Bronx
# Woodrow       Entire home/apt              Donna       Staten Island
# Woodside      Entire home/apt               Paul              Queens
#               Private room                Justin              Queens
#               Shared room                   Emma              Queens
#
#                                latitude  longitude  price  minimum_nights  \
# neighbourhood room_type
# Allerton      Entire home/apt  40.86466  -73.85709    125               2
#               Private room     40.86870  -73.85240     35               7
# Arden Heights Entire home/apt  40.56033  -74.18259     75               1
#               Private room     40.54312  -74.17388     41               2
# Arrochar      Entire home/apt  40.59251  -74.06479    250               2
# ...                                 ...        ...    ...             ...
# Woodlawn      Shared room      40.89785  -73.86977     70               2
# Woodrow       Entire home/apt  40.53884  -74.19826    700               7
# Woodside      Entire home/apt  40.74723  -73.89706    120               3
#               Private room     40.75038  -73.90334     70              30
#               Shared room      40.74508  -73.90291     65               2
#
#                                number_of_reviews last_review  \
# neighbourhood room_type
# Allerton      Entire home/apt                271  2019-06-20
#               Private room                     2  2018-07-23
# Arden Heights Entire home/apt                 20  2019-01-08
#               Private room                     7  2019-01-08
# Arrochar      Entire home/apt                 21  2019-05-22
# ...                                          ...         ...
# Woodlawn      Shared room                      2  2018-12-02
# Woodrow       Entire home/apt                  0         NaN
# Woodside      Entire home/apt                 60  2019-07-04
#               Private room                    25  2019-05-31
#               Shared room                      8  2019-06-29
#
#                                reviews_per_month  \
# neighbourhood room_type
# Allerton      Entire home/apt               2.84
#               Private room                  0.17
# Arden Heights Entire home/apt               1.55
#               Private room                  0.71
# Arrochar      Entire home/apt               0.26
# ...                                          ...
# Woodlawn      Shared room                   0.11
# Woodrow       Entire home/apt                NaN
# Woodside      Entire home/apt               1.59
#               Private room                  0.22
#               Shared room                   3.04
#
#                                calculated_host_listings_count  \
# neighbourhood room_type
# Allerton      Entire home/apt                               2
#               Private room                                  1
# Arden Heights Entire home/apt                               1
#               Private room                                  1
# Arrochar      Entire home/apt                               4
# ...                                                       ...
# Woodlawn      Shared room                                   2
# Woodrow       Entire home/apt                               1
# Woodside      Entire home/apt                               3
#               Private room                                  1
#               Shared room                                   1
#
#                                availability_365
# neighbourhood room_type
# Allerton      Entire home/apt               347
#               Private room                   90
# Arden Heights Entire home/apt                 6
#               Private room                    0
# Arrochar      Entire home/apt               333
# ...                                         ...
# Woodlawn      Shared room                     0
# Woodrow       Entire home/apt                 0
# Woodside      Entire home/apt               281
#               Private room                  324
#               Shared room                    89
#
# [540 rows x 13 columns]

# %% [markdown]
# H) Replace the values within "room_type" with numerical values, i.e. 0 for "private room", 1 for "Entire home/apt", and 2 for "Shared room". </p>
# Save the new dataframe again under the name "df".

# %%
df=df.replace({"Private room":0,"Entire home/apt":1,"Shared room":2})
df["room_type"]
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 48890    0
# 48891    0
# 48892    1
# 48893    2
# 48894    0
# Name: room_type, Length: 48895, dtype: int64

# %% [markdown]
# I) Display a bar chart using the distplot (from the seaborn library) that shows the neighbourhood on the x-axis and the number of listings on the y-axis.

# %%
sns.displot(x="neighbourhood", y="n_listings", data=df_copy)

# %% [markdown]
# J) Scale the column "price" and the column "number_of_reviews" using a method that seems appropriate in your opinion. </p>
# Save the new dataframe again under the name "df".

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df["price"] = scaler.fit_transform(df["price"].values.reshape(-1,1))
df["number_of_reviews"] = scaler.fit_transform(df["number_of_reviews"].values.reshape(-1,1))
df.head()
# Out:
#      id                                      listing_name    host_name  \
# 0  2539                Clean & quiet apt home by the park         John
# 1  2595                             Skylit Midtown Castle     Jennifer
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth
# 3  3831                   Cozy Entire Floor of Brownstone  LisaRoxanne
# 4  5022  Entire Apt: Spacious Studio/Loft by central park        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude  room_type   price  \
# 0            Brooklyn    Kensington  40.64749  -73.97237          0  0.0149
# 1           Manhattan       Midtown  40.75362  -73.98377          1  0.0225
# 2           Manhattan        Harlem  40.80902  -73.94190          0  0.0150
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976          1  0.0089
# 4           Manhattan   East Harlem  40.79851  -73.94399          1  0.0080
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1           0.014308  2018-10-19               0.21
# 1               1           0.071542  2019-05-21               0.38
# 2               3           0.000000         NaN                NaN
# 3               1           0.429253  2019-07-05               4.64
# 4              10           0.014308  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %% [markdown]
# <h2>3. Cleaning Data</h2>
#
# Dataset used: "defaults.xls"

# %%
# Place all packages you need here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# A) Load the dataset "defaults.xls" and save it under the name "defaults". Display the datatypes of all columns of the dataset "defaults.xls".

# %%
defaults = pd.read_excel("/Users/vitoraronis/Documents/TechLabs/defaults.xls")
defaults.dtypes
# Out:
# ID               int64
# CREDIT_LIMIT     int64
# SEX             object
# EDUCATION       object
# MARRIAGE        object
# AGE              int64
# default          int64
# dtype: object

# %% [markdown]
# B) Some column(s) might not be needed. Get rid of them. Explain why you get rid of the respective column(s). </p>
# Save the new dataframe again under the name "defaults".

# %%
# I will drop ID because this data will not be used to predict default and does not add value to the dataset analysis
defaults.drop("ID", axis = 1, inplace=True)
defaults.head()
# Out:
#    CREDIT_LIMIT     SEX   EDUCATION MARRIAGE  AGE  default
# 0         20000  female  university  married   24        1
# 1        120000  female  university   single   26        1
# 2         90000  female  university   single   34        0
# 3         50000  female  university  married   37        0
# 4         50000    male  university  married   57        0

# %% [markdown]
# C) Convert all categorical values into dummy variables. Only include columns with valuable information. </p>
# Save the new dataframe again under the name "defaults".

# %%
dummy = pd.get_dummies(defaults["SEX"])
defaults = pd.concat([defaults, dummy], axis=1)
defaults.drop("SEX", axis = 1, inplace=True)
defaults.head()
# Out:
#    CREDIT_LIMIT   EDUCATION MARRIAGE  AGE  default  female  male
# 0         20000  university  married   24        1       1     0
# 1        120000  university   single   26        1       1     0
# 2         90000  university   single   34        0       1     0
# 3         50000  university  married   37        0       1     0
# 4         50000  university  married   57        0       0     1

# %% [markdown]
# D) In order to run a model, we have to define now the X and y variables. Set the y values to the "default" (either 0 or 1). The remaining columns represent the X values.

# %%
#I did not learned this part of the course yet. However I would assume that the Y variable is Default
# because this is what we are trying to predict. X variables are the other columns that will generate de model

# %% [markdown]
# <h2>4. Further Data Analysis</h2>

# %% [markdown]
# A) Please evaluate the importance of each feature of the X values on the y value of the previous exercise using any tree ensamble algorithm and display the results graphically. Please comment your findings. Please tell us what you did and why you did it.

# %%
# I still don´t know this topic

# %% [markdown]
# B) Please assess how accuarely we can predict, whether a customer will default or not using Support Vector Machines. As always plase explain your work.

# %%
# I still don´t know this topic

# %% [markdown]
# C) Now let's see how accurate the XGBoost algorithm can predict, whether a customer will default or not better than the previous SVM. Please give us the accuracy score and standard deviation. Choose an appropiate model for testing and training.

# %%
# I still don´t know this topic
